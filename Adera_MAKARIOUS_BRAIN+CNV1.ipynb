# %%
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
from IPython import display
from tensorflow.keras.constraints import max_norm

import pandas as pd

# %%
import pandas as pd

#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g_onely_main.txt',delimiter='\t',engine='python')
first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_genec_only_main_14.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('Adera_Complete_data_base_10_july_v1_2_38pm.txt',delimiter=',',engine='python')

first_data_adera
# Out:
#          Gene     CNA  Freq  chromosome        start          end  strand  \
# 0       A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1       A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 2       A4GNT     AMP   6.0           3  138123713.0  138132390.0       3
# 3      AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4       AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# ...       ...     ...   ...         ...          ...          ...     ...
# 12979    ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12980    ZUP1  HOMDEL   6.5           6  116635618.0  116668794.0       3
# 12981    ZUP1  HOMDEL   6.3           6  116635618.0  116668794.0       3
# 12982    ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983     ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 2             Esophageal_Adenocarcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12980           Prostate_Adenocarcinoma
# 12981                    Uveal Melanoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [12984 rows x 8 columns]

# %%
first_data_adera1= first_data_adera.dropna(axis = 0, how ='any')
first_data_adera1
#first_data_adera2 = first_data_adera1.sort_values(by=['Freq'], ascending=[ False])
first_data_adera3 = first_data_adera1.sort_values(by=['Gene', 'Cancer_type', 'Freq'], ascending=[True, True, False])
first_data_adera3
first_data_adera4 = first_data_adera3.drop_duplicates(subset=['Gene'], keep='first')
first_data_adera4
# Out:
#           Gene     CNA  Freq  chromosome        start          end  strand  \
# 0        A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1        A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 3       AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4        AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# 7      AADACL2     AMP   8.2           3  151733916.0  151761339.0      77
# ...        ...     ...   ...         ...          ...          ...     ...
# 12977   ZSWIM4     AMP  12.1          19   13795443.0   13832254.0      77
# 12978   ZSWIM7     AMP   9.1          17   15976560.0   15999717.0       3
# 12979     ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12982     ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983      ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# 7      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12977             Serous_Ovarian_Cancer
# 12978                           Sarcoma
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [7058 rows x 8 columns]

# %%
first_data_adera["Cancer_type"].unique()
# Out:
# array(['Testicular_Germ_Cell_Tumors', 'Cervical_Squamous_Cell_Carcinoma',
#        'Esophageal_Adenocarcinoma', 'Renal_Clear_Cell_Carcinoma',
#        'Head_and_Neck_Squamous', 'Serous_Ovarian_Cancer',
#        'Colorectal_Adenocarcinoma', 'Liver_Hepatocellular_Carcinoma',
#        'Breast_Invasive_Ductal_Carcinoma', 'Stomach_Adenocarcinoma',
#        'Uterine_Corpus_Endometrial_Carcinoma',
#        'Diffuse_Large B-Cell_Lymphoma', 'Cholangiocarcinoma',
#        'Uveal Melanoma', 'Bladder_Urothelial_Carcinoma', 'Sarcoma',
#        'Prostate_Adenocarcinoma', 'Lung', 'Adrenocortical_Carcinoma',
#        'Glioblastoma_Multiforme', 'Skin_Cutaneous_Melanoma',
#        'Brain_Lower_Grade_Glioma'], dtype=object)

# %%
First_data_adera3a= first_data_adera3[first_data_adera3['Cancer_type'] == 'Brain_Lower_Grade_Glioma']
First_data_adera3b= first_data_adera3[first_data_adera3['Cancer_type'] == 'Glioblastoma_Multiforme']

First_data_adera3c = pd.concat([First_data_adera3a, First_data_adera3b])

# %%
First_data_adera3c['Cancer_type'].unique()
# Out:
# array(['Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme'],
#       dtype=object)

# %%
import tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(First_data_adera3c["CNA"])
Adera_CNA= encoder.transform(First_data_adera3c["CNA"])

Adera_CNA1= to_categorical(Adera_CNA,num_classes=4)
#type(first_data_adera["Freq"])
#Adera_CNA1=first_data_adera['CNA']
Adera_CNA1.shape #rember to update because there are genes written in one or more diseases.
Adera_CNA1
type(First_data_adera3c ['CNA'])

#Input_net_Adera = np.concatenate((Adera_freq.T,Adera_CNA1), axis=None)
#Input_net_Adera1=Input_net_Adera.reshape(5,6918).T

Input_net_Adera1=Adera_CNA1
Input_net_Adera1.shape # number of samples,number of 4 states
Adera_chromosome=First_data_adera3c['chromosome']
Adera_chromosome1=np.array(Adera_chromosome)
Adera_chromosome2=Adera_chromosome1.reshape(Input_net_Adera1.shape[0],1)

Adera_start=First_data_adera3c['start']
Adera_start1=np.array(Adera_start)
Adera_start2=Adera_start1.reshape(Input_net_Adera1.shape[0],1)

Adera_end=First_data_adera3c['end']
Adera_end1=np.array(Adera_end)
Adera_end2=Adera_end1.reshape(Input_net_Adera1.shape[0],1)

Adera_strand=First_data_adera3c['strand']
Adera_strand1=np.array(Adera_strand)
Adera_strand2=Adera_strand1.reshape(Input_net_Adera1.shape[0],1)

Adera_freq=First_data_adera3c['Freq']
Adera_freq1=np.array(Adera_freq)
Adera_freq2=Adera_freq1.reshape(Input_net_Adera1.shape[0],1)
#normalise chromsoem numbers
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_chromosome3 = Adera_chromosome2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_chromosome4= scaler.fit_transform(Adera_chromosome3)



#####normalise start values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_start3 = Adera_start2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_start4= scaler.fit_transform(Adera_start3)

####normalise end values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_end3 = Adera_end2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_end4= scaler.fit_transform(Adera_end3)

######normalise stand
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_strand3 = Adera_strand2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_strand4= scaler.fit_transform(Adera_strand3)
Adera_chromosome4.shape
k1=First_data_adera3c["Cancer_type"].unique()
k1.shape[0]
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,adera_matrix), axis=1)
Adera_CNA1
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome2,Adera_start2,Adera_end2,Adera_strand2,Adera_freq2), axis=1)
Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome4,Adera_start4,Adera_end4,Adera_strand4), axis=1)
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_start2,Adera_end2), axis=1)
#Input_net_Adera2=adera_matrix
Input_net_Adera2.shape
Output_net_Adera=First_data_adera3c[["Cancer_type"]]
Output_net_Adera

from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#encoder.fit(Output_net_Adera)
#Output_net_Adera1 = encoder.transform(Output_net_Adera)

#Output_net_Adera1 = to_categorical(Output_net_Adera1,num_classes=3)
#Output_net_Adera1



encoder = LabelEncoder()
encoder.fit(First_data_adera3c[["Cancer_type"]])
Output_net_Adera1 = encoder.transform(First_data_adera3c[["Cancer_type"]])

Output_net_Adera2= to_categorical(Output_net_Adera1 ,num_classes=k1.shape[0])
Output_net_Adera2.shape
Output_net_Adera2
Input_Adera_numpy2=Input_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,8) #7 input values

Output_net_Adera3=Output_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,k1.shape[0]) #7 cancer types
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\preprocessing\_label.py:97: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\preprocessing\_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
Output_net_Adera3.shape
# Out:
# (113, 1, 1, 2)

# %%
import numpy as np
import tensorflow.keras.backend as K
from scipy.optimize import brentq
from scipy.interpolate import interp1d


def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def fp(y_true, y_pred):
    return K.sum(K.cast((1-y_true)*y_pred, 'float'), axis=0)

def fn(y_true, y_pred):
    return K.sum(K.cast(y_true*(1-y_pred), 'float'), axis=0)

def tp(y_true, y_pred):
    return K.sum(K.cast(y_true*y_pred, 'float'), axis=0)

def tn(y_true, y_pred):
    return K.sum(K.cast((1-y_true)*(1-y_pred), 'float'), axis=0)


def p(y_true, y_pred):
    p = tp(y_true, y_pred) / (tp(y_true, y_pred) + fp(y_true, y_pred) + K.epsilon())
    return K.mean(p)

def r(y_true, y_pred):
    r = tp(y_true, y_pred) / (tp(y_true, y_pred) + fn(y_true, y_pred) + K.epsilon())
    return K.mean(r)



def f1(y_true, y_pred):
    p = tp(y_true, y_pred) / (tp(y_true, y_pred) + fp(y_true, y_pred) + K.epsilon())
    r = tp(y_true, y_pred) / (tp(y_true, y_pred) + fn(y_true, y_pred) + K.epsilon())

    f1 = 2*p*r / (p+r+K.epsilon())
    return K.mean(f1)

def eer(y_true, y_pred):
    fpr = fp(y_true, y_pred)
    tpr = tp(y_true, y_pred)
    threshold = 0.5
    eer = brentq(lambda x: 1. - x - interp1d(fpr, tpr)(x), 0., 1.)
    return eer

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
import matplotlib.pyplot as plot
#MODEL1
data_adera4 = pd.DataFrame({'Entities':['Accuracy', 'Precision', 'Recall', 'F1'],
        'Values':[0.9097, 0.6134, 0.6149 , 0.6060]})
#MODEL2
data_adera4 = pd.DataFrame({'Entities':['Accuracy', 'Precision', 'Recall', 'F1'],
        'Values':[0.9173, 0.6526, 0.6605 , 0.6493]})
adera_colours=['blue', 'red', 'green', 'orange']
#adera_results=pd.DataFrame(data_adera4)
ax = data_adera4.plot.bar(x='Entities', y='Values', rot=0,color=adera_colours)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 #print(k_adera.history.keys())
#       2 #print(k_adera.history['val_loss'])
#       3 #print(k_adera.history['val_accuracy'])
#       4 #print(k_adera.history['mape'])
# ----> 5 results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
#       6 import matplotlib.pyplot as plot
#       7 #MODEL1
#
# NameError: name 'grace_model' is not defined

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import SpecificityAtSensitivity, AUC
#from tensorflow.keras import regularizers
es_ADERA = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=300)

from random import sample

class_0_indices = np.where(Output_net_Adera3 == 0)[0]
class_1_indices = np.where(Output_net_Adera3 == 1)[0]

num_samples_class_0 = len(class_0_indices)
num_samples_class_1 = len(class_1_indices)

target_size = min(num_samples_class_0, num_samples_class_1)

undersampled_indices = np.concatenate([
    sample(class_0_indices.tolist(), target_size),
    class_1_indices
])

Input_Adera_undersampled = Input_Adera_numpy2[undersampled_indices]
Output_net_Adera_undersampled = Output_net_Adera3[undersampled_indices]




grace_model = tf.keras.Sequential([

 tf.keras.layers.Dense(2, activation='sigmoid'),
# tf.keras.layers.Dense(2, activation='softmax'),
 #tf.keras.layers.Dense(2, activation='softplus')


      ])





optimizer_Adera=tf.keras.optimizers.Adamax(learning_rate=2*1e-2, clipnorm = .08)
grace_model.compile(optimizer=optimizer_Adera, loss='CategoricalFocalCrossentropy', metrics=[ 'accuracy', SpecificityAtSensitivity(0.5),AUC()  ])
#grace_model.compile(optimizer=optimizer_Adera, loss='binary_crossentropy',metrics=['accuracy',p,r,f1])
k_adera = grace_model.fit(Input_Adera_undersampled, Output_net_Adera_undersampled, verbose=1, validation_split=0.49, epochs=200, batch_size=10, callbacks=[es_ADERA])
#k_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=200,batch_size=10, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=350,batch_size=250, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8
# Out:
# Epoch 1/200
# 12/12 [==============================] - 2s 61ms/step - loss: 0.0235 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9391 - auc: 0.8431 - val_loss: 0.0160 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9438
# Epoch 2/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0215 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.9110 - val_loss: 0.0152 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9475
# Epoch 3/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.9174 - val_loss: 0.0150 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9479
# Epoch 4/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0197 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.9091 - val_loss: 0.0155 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9289
# Epoch 5/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8964 - val_loss: 0.0155 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9292
# Epoch 6/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0187 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8970 - val_loss: 0.0153 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9291
# Epoch 7/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0189 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.9003 - val_loss: 0.0150 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9392
# Epoch 8/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0185 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.9054 - val_loss: 0.0151 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9291
# Epoch 9/200
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0184 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8977 - val_loss: 0.0150 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9291
# Epoch 10/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0183 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8971 - val_loss: 0.0151 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9276
# Epoch 11/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0182 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8955 - val_loss: 0.0151 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9275
# Epoch 12/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0182 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8949 - val_loss: 0.0150 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9280
# Epoch 13/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0182 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8946 - val_loss: 0.0151 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9266
# Epoch 14/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0181 - accuracy: 0.9130 - specificity_at_sensitivity: 0.9304 - auc: 0.8943 - val_loss: 0.0148 - val_accuracy: 0.9459 - val_specificity_at_sensitivity: 0.9640 - val_auc: 0.9285
# Epoch 15/200
#  1/12 [=>............................] - ETA: 0s - loss: 0.0152 - accuracy: 0.9000 - specificity_at_sensitivity: 0.9000 - auc: 0.9000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 46
#      44 grace_model.compile(optimizer=optimizer_Adera, loss='CategoricalFocalCrossentropy', metrics=[ 'accuracy', SpecificityAtSensitivity(0.5),AUC()  ])
#      45 #grace_model.compile(optimizer=optimizer_Adera, loss='binary_crossentropy',metrics=['accuracy',p,r,f1])
# ---> 46 k_adera = grace_model.fit(Input_Adera_undersampled, Output_net_Adera_undersampled, verbose=1, validation_split=0.49, epochs=200, batch_size=10, callbacks=[es_ADERA])
#      47 #k_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=200,batch_size=10, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=350,batch_size=250, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:1791, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 if getattr(self, "_eval_data_handler", None) is None:
#    1776     self._eval_data_handler = data_adapter.get_data_handler(
#    1777         x=val_x,
#    1778         y=val_y,
#    (...)
#    1789         pss_evaluation_shards=self._pss_evaluation_shards,
#    1790     )
# -> 1791 val_logs = self.evaluate(
#    1792     x=val_x,
#    1793     y=val_y,
#    1794     sample_weight=val_sample_weight,
#    1795     batch_size=validation_batch_size or batch_size,
#    1796     steps=validation_steps,
#    1797     callbacks=callbacks,
#    1798     max_queue_size=max_queue_size,
#    1799     workers=workers,
#    1800     use_multiprocessing=use_multiprocessing,
#    1801     return_dict=True,
#    1802     _use_cached_eval_dataset=True,
#    1803 )
#    1804 val_logs = {
#    1805     "val_" + name: val for name, val in val_logs.items()
#    1806 }
#    1807 epoch_logs.update(val_logs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\training.py:2189, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2187 self._test_counter.assign(0)
#    2188 callbacks.on_test_begin()
# -> 2189 for (
#    2190     _,
#    2191     dataset_or_iterator,
#    2192 ) in data_handler.enumerate_epochs():  # Single epoch.
#    2193     self.reset_metrics()
#    2194     with data_handler.catch_stop_iteration():
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\src\engine\data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1329 """Yields `(epoch, tf.data.Iterator)`."""
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#    1333         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:506, in DatasetV2.__iter__(self)
#     504 if context.executing_eagerly() or ops.inside_function():
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#     508   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     509                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     706   if (components is not None or element_spec is not None):
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     746   assert len(fulltype.args[0].args[0].args) == len(
#     747       self._flat_output_types)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3451, in make_iterator(dataset, iterator, name)
#    3449 if tld.is_eager:
#    3450   try:
# -> 3451     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3452       _ctx, "MakeIterator", name, dataset, iterator)
#    3453     return _result
#    3454   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Plotting multiple metrics
plt.figure(figsize=(16, 5))

# Plot Accuracy
plt.subplot(1, 3, 1)
plt.plot(k_adera.history['accuracy'])
plt.plot(k_adera.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Loss
plt.subplot(1, 3, 2)
plt.plot(k_adera.history['loss'])
plt.plot(k_adera.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Specificity at Sensitivity 0.5
plt.subplot(1, 3, 3)
plt.plot(k_adera.history['specificity_at_sensitivity_8'])
plt.plot(k_adera.history['specificity_at_sensitivity_8'])
plt.title('Specificity at Sensitivity 0.5')
plt.ylabel('Specificity')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Plot AUC
plt.figure(figsize=(8, 5))
plt.plot(k_adera.history['auc_8'])
plt.plot(k_adera.history['val_auc_8'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
import matplotlib.pyplot as plot
#MODEL_
data_adera4 = pd.DataFrame({'Entities':['Accuracy', 'Precision', 'Recall', 'F1'],
        'Values':[0.9097, 0.6134, 0.6149 , 0.6060]})
#MODEL2
data_adera4 = pd.DataFrame({'Entities':['Accuracy', 'Precision', 'Recall', 'F1'],
        'Values':[0.9173, 0.6526, 0.6605 , 0.6493]})


#MODEL_brain
data_adera4 = pd.DataFrame({'Entities':['Accuracy', 'Precision', 'Recall', 'F1'],
        'Values':[0.9292, 0.5250, 0.8403 , 0.6446]})
adera_colours=['blue', 'red', 'green', 'orange']
#adera_results=pd.DataFrame(data_adera4)
ax = data_adera4.plot.bar(x='Entities', y='Values', rot=0,color=adera_colours)
# Out:
# 1/1 [==============================] - 0s 50ms/step - loss: 0.6575 - accuracy: 0.9292 - p: 0.5250 - r: 0.8403 - f1: 0.6446

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
# summarize history for accuracy
plt.plot(k_adera.history['accuracy'])
plt.plot(k_adera.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
axes = plt.gca()
#axes.set_ylim([-0.005,0.005])
plt.plot(k_adera.history['loss'])
plt.plot(k_adera.history['val_loss'])
#########################
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#plt.title('model mape')
#plt.plot(k_adera.history['mean_squared_error'])
#plt.plot(k_adera.history['val_mape'])
#plt.plot(k_adera.history['mape'])
#plt.ylabel('mape')
#plt.xlabel('epoch')
#plt.show()
#plt.title('model mae')
#plt.plot(k_adera.history['val_mae'])
#plt.plot(k_adera.history['mae'])
#plt.show()
# Out:
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6569 - accuracy: 0.9292

# %%
grace_model.save("adera+90+80b+sigmoid2+Brain")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d515fc4ce318> in <cell line: 1>()
# ----> 1 grace_model.save("adera+90+80b+sigmoid2+Brain")
#
# NameError: name 'grace_model' is not defined

# %%
adera_47_40_model = tf.keras.saving.load_model("adera+90+80b+sigmoid2+Brain")

# %%
First_data_adera3c["Cancer_type"].unique()
data_adera= {
    "types":First_data_adera3c["Cancer_type"].unique(),
    "values": [0, 1]
}
import random
from keras.utils.np_utils import to_categorical


 # print(adera_test)
#Input_Adera_numpy2[adera_test].shape
#data_adera

threshold = 0.85  # Set the threshold for prediction

num_runs = 3
accuracies = []

for run in range(num_runs):
    adera_test = [random.randint(0, Adera_chromosome4.shape[0]-1) for _ in range(99)]
    correct_predictions = 0
    total_predictions = 0

    for adera_test1 in adera_test:
        test_mac = Input_Adera_numpy2[adera_test1].reshape(1, 1, 1, 8)
        adera_result = adera_47_40_model.predict(test_mac)
        print("adera_result=",adera_result)


        adera_result_thresholded = (adera_result >= threshold).astype(int)
        adera_result5 = np.argmax(adera_result_thresholded)
       # print("adera_result5=",adera_result5)

        if data_adera['types'][adera_result5] == First_data_adera3c['Cancer_type'].iloc[adera_test1]:
            #print("data_adera['types'][adera_result5] =", data_adera['types'][adera_result5])
           # print("data_adera['types'][adera_result5]=",data_adera['types'][adera_result5])
            correct_predictions += 1

        total_predictions += 1

    accuracy = correct_predictions / total_predictions
    accuracies.append(accuracy)

mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)

print("Mean accuracy:", mean_accuracy)
print("Standard deviation of accuracy:", std_accuracy)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.00980041 0.9900673 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1374681 0.8624059]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.00329515 0.9974573 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.12216564 0.87868154]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03437506 0.965352  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01746572 0.9823495 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 85ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 117ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 89ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 95ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 267ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 233ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 212ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 105ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 96ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 107ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 58ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 97ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 83ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 100ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 108ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.05811961 0.94242275]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 69ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 87ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 59ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 62ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 51ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# data_adera['types'][adera_result5] = Brain_Lower_Grade_Glioma
# data_adera['types'][adera_result5]= Brain_Lower_Grade_Glioma
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 53ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03290707 0.9669432 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 79ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 67ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 54ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 60ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 80ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 55ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 65ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 52ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 153ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.12805742 0.8724431 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.03437506 0.965352  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00980041 0.9900673 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 49ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.01272298 0.98688483]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 51ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 45ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 48ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.01272298 0.98688483]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 43ms/step
# adera_result= [[[[0.03290707 0.9669432 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 38ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 47ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01265143 0.9869634 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.12805742 0.8724431 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.01269122 0.9869195 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# ...
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01746572 0.9823495 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# adera_result5= 1
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.22295333 0.7771023 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.13650487 0.86344606]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02259145 0.9767763 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01750956 0.98230106]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.22052212 0.77988297]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.00330034 0.9974517 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.1369586 0.8629619]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.2153977 0.7852418]]]]
# adera_result5= 0
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.00329515 0.9974573 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1365516 0.8633962]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01266084 0.9869526 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.13650487 0.86344606]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# adera_result5= 1
# data_adera['types'][adera_result5] = Glioblastoma_Multiforme
# data_adera['types'][adera_result5]= Glioblastoma_Multiforme
# Mean accuracy: 0.8720538720538721
# Standard deviation of accuracy: 0.004761661826172016

# %%
First_data_adera3c["Cancer_type"].unique()
data_adera= {
    "types":First_data_adera3c["Cancer_type"].unique(),
    "values": [0, 1]
}

data_adera

import random
#from np_utils import to_categorical


 # print(adera_test)
#Input_Adera_numpy2[adera_test].shape
#data_adera

threshold = 0.1 # Set the threshold for prediction

num_runs = 3
accuracies = []
y_true_adera=[]
y_pred_adera=[]
for run in range(num_runs):
    adera_test = [random.randint(0, Adera_chromosome4.shape[0]-1) for _ in range(99)]
    correct_predictions = 0
    total_predictions = 0

    for adera_test1 in adera_test:
        test_mac = Input_Adera_numpy2[adera_test1].reshape(1, 1, 1, 8)
        adera_result = adera_47_40_model.predict(test_mac)
        print("adera_result=",adera_result)


        adera_result_thresholded = (adera_result >= threshold).astype(int)
        adera_result5 = np.argmax(adera_result_thresholded)
       # print("adera_result5=",adera_result5)
        y_true_adera.append(First_data_adera3c['Cancer_type'].iloc[adera_test1])
        y_pred_adera.append(data_adera['types'][adera_result5])
        #if data_adera['types'][adera_result5] == First_data_adera3c['Cancer_type'].iloc[adera_test1]:
            #print("data_adera['types'][adera_result5] =", data_adera['types'][adera_result5])
           # print("data_adera['types'][adera_result5]=",data_adera['types'][adera_result5])
           # correct_predictions += 1

        #total_predictions += 1

    #accuracy = correct_predictions / total_predictions
    #accuracies.append(accuracy)

#mean_accuracy = np.mean(accuracies)
#std_accuracy = np.std(accuracies)

print(y_true_adera)
print(y_pred_adera)
#print("Standard deviation of accuracy:", std_accuracy)

from sklearn.metrics import confusion_matrix

print(y_true_adera)
print(y_pred_adera)

##y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
 ##y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
mkr1=confusion_matrix(y_true_adera, y_pred_adera, labels=[First_data_adera3c["Cancer_type"].unique()[0], First_data_adera3c["Cancer_type"].unique()[1]],normalize='all')

#array([[2, 0, 0],
 #      [0, 0, 1],
   #3    [1, 0, 2]])
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

mkr1_display = ConfusionMatrixDisplay(mkr1).plot()

accuracy_adera= (mkr1[0][0] + mkr1[1][1]) / (mkr1[0][0] + mkr1[1][1]+mkr1[0][1] + mkr1[1][0])

print(accuracy_adera)

precsioin_adera= (mkr1[0][0]) / (mkr1[0][1]+mkr1[0][0] )
print(precsioin_adera)

recal_adera= (mkr1[0][0]) / (mkr1[0][0] + mkr1[1][0])
print(recal_adera)


f1_adera=2*(precsioin_adera*recal_adera)/(precsioin_adera+recal_adera)
print(f1_adera)


data_adera=[]
from matplotlib import cm
adera_colours=['blue', 'red', 'green', 'orange']

import pandas as pd

# intialise data of lists.
data_adera = pd.DataFrame({'Name':['Accuracy', 'Precision', 'Recall', 'F1 Score'],
        'Value':[accuracy_adera, precsioin_adera, recal_adera, f1_adera]})

# Create DataFrame
#data_adera2 = pd.DataFrame(data_adera)

# Print the output.
#data_adera2.plot()
plot = data_adera.plot(x='Name', y='Value', rot=0, kind="bar", ylabel="Value",color=adera_colours)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
# Out:
# 1/1 [==============================] - 0s 152ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13650487 0.86344606]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.1365516 0.8633962]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05702207 0.9429012 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1374681 0.8624059]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01750956 0.98230106]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.12216564 0.87868154]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02236929 0.9770189 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.1251537 0.8755288]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.1365516 0.8633962]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0226126 0.9767557]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.00327364 0.9974745 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.2153977 0.7852418]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.03185876 0.96806383]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# 1/1 [==============================] - 0s 44ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.10051692 0.9005696 ]]]]
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.05715462 0.9427588 ]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# 1/1 [==============================] - 0s 46ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.1370564 0.8628574]]]]
# 1/1 [==============================] - 0s 42ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# 1/1 [==============================] - 0s 38ms/step
# adera_result= [[[[0.09946923 0.90167844]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.1374681 0.8624059]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.02253187 0.9768442 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21652316 0.7841369 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.22052212 0.77988297]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13694538 0.8629759 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.01750956 0.98230106]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13674921 0.8631854 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02248198 0.9768968 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.0567836  0.94383574]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01269122 0.9869195 ]]]]
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05891495 0.9408747 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.10067372 0.90039164]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05891495 0.9408747 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.22052212 0.77988297]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13712467 0.86278445]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.21880785 0.78163433]]]]
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.13477021 0.8652943 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.01263176 0.9869842 ]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.22052212 0.77988297]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03259125 0.9672822 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05818473 0.9423635 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.05784982 0.94200456]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02257695 0.9767946 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.2184322 0.7821089]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05892447 0.94086206]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05891495 0.9408747 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02245848 0.97692466]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03437506 0.965352  ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.0225402  0.97683465]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02252721 0.9768493 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# 1/1 [==============================] - 0s 34ms/step
# adera_result= [[[[0.03259962 0.9672729 ]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.13660078 0.86334187]]]]
# 1/1 [==============================] - 0s 41ms/step
# adera_result= [[[[0.13667674 0.8632626 ]]]]
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.01260301 0.9870166 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# 1/1 [==============================] - 0s 32ms/step
# adera_result= [[[[0.1368877  0.86303747]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.05702516 0.94289577]]]]
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.02246535 0.9769166 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.14125639 0.85825986]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.13685545 0.86307186]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.02260732 0.9767611 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.09912956 0.9020181 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.13621739 0.8636842 ]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.05820712 0.9416002 ]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.0058688 0.9954813]]]]
# 1/1 [==============================] - 0s 40ms/step
# adera_result= [[[[0.13619412 0.8637774 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# 1/1 [==============================] - 0s 30ms/step
# adera_result= [[[[0.01273418 0.986872  ]]]]
# 1/1 [==============================] - 0s 49ms/step
# adera_result= [[[[0.09823193 0.9029613 ]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# 1/1 [==============================] - 0s 35ms/step
# adera_result= [[[[0.01265541 0.986959  ]]]]
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.0572025  0.94269884]]]]
# 1/1 [==============================] - 0s 37ms/step
# adera_result= [[[[0.02247401 0.9769079 ]]]]
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# 1/1 [==============================] - 0s 36ms/step
# adera_result= [[[[0.02243916 0.9769444 ]]]]
# 1/1 [==============================] - 0s 33ms/step
# adera_result= [[[[0.02244864 0.976935  ]]]]
# 1/1 [==============================] - 0s 39ms/step
# adera_result= [[[[0.05700701 0.9429144 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.05891495 0.9408747 ]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.2153977 0.7852418]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.02248198 0.9768968 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.03323251 0.9665932 ]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.12805742 0.8724431 ]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.00329246 0.9974594 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 27ms/step
# adera_result= [[[[0.0226126 0.9767557]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# 1/1 [==============================] - 0s 20ms/step
# adera_result= [[[[0.0126501 0.986965 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.05869773 0.9417778 ]]]]
# 1/1 [==============================] - 0s 101ms/step
# adera_result= [[[[0.00328824 0.99746245]]]]
# 1/1 [==============================] - 0s 92ms/step
# adera_result= [[[[0.05862993 0.9411727 ]]]]
# 1/1 [==============================] - 0s 31ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# 1/1 [==============================] - 0s 72ms/step
# adera_result= [[[[0.01263909 0.9869763 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05712646 0.9427812 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03280104 0.9670505 ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.13483566 0.86521643]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.01271732 0.98689055]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.0225352 0.9768407]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.03359918 0.96620125]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.10088675 0.90015674]]]]
# 1/1 [==============================] - 0s 26ms/step
# adera_result= [[[[0.02248198 0.9768968 ]]]]
# 1/1 [==============================] - 0s 28ms/step
# adera_result= [[[[0.21805242 0.78243965]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03261223 0.9672586 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.13729946 0.862598  ]]]]
# 1/1 [==============================] - 0s 24ms/step
# adera_result= [[[[0.03303893 0.9667885 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.0226126 0.9767557]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.05928499 0.9411107 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.13699895 0.86291873]]]]
# 1/1 [==============================] - 0s 29ms/step
# adera_result= [[[[0.01748827 0.98232466]]]]
# 1/1 [==============================] - 0s 25ms/step
# adera_result= [[[[0.1389287 0.8607491]]]]
# 1/1 [==============================] - 0s 23ms/step
# adera_result= [[[[0.02255577 0.9768155 ]]]]
# 1/1 [==============================] - 0s 22ms/step
# adera_result= [[[[0.03327841 0.9665451 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03290707 0.9669432 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.22064653 0.77975035]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01750956 0.98230106]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.00329515 0.9974573 ]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.03265235 0.96721274]]]]
# 1/1 [==============================] - 0s 21ms/step
# adera_result= [[[[0.01269122 0.9869195 ]]]]
# ['Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multifor ...
# ['Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', ...
# ['Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multifor ...
# ['Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', 'Brain_Lower_Grade_Glioma', 'Brain_Lower_Grade_Glioma', 'Glioblastoma_Multiforme', 'Glioblastoma_Multiforme', ...
# 0.6767676767676768
# 0.4444444444444444
# 0.0851063829787234
# 0.14285714285714285
