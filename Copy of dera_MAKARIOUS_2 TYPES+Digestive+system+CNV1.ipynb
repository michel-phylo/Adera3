# %%
from absl import logging

import tensorflow as tf

import tensorflow_hub as hub
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import seaborn as sns
import glob
import imageio
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time
from IPython import display
from tensorflow.keras.constraints import max_norm

import pandas as pd

# %%
import pandas as pd

#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g_onely_main.txt',delimiter='\t',engine='python')
first_data_adera=pd.read_table('updated_ADERA_GENES_6500_gene8g.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('updated_ADERA_GENES_6500_genec_only_main_14.txt',delimiter='\t',engine='python')
#first_data_adera=pd.read_table('Adera_Complete_data_base_10_july_v1_2_38pm.txt',delimiter=',',engine='python')

first_data_adera
# Out:
#          Gene     CNA  Freq  chromosome        start          end  strand  \
# 0       A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1       A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 2       A4GNT     AMP   6.0           3  138123713.0  138132390.0       3
# 3      AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4       AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# ...       ...     ...   ...         ...          ...          ...     ...
# 12979    ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12980    ZUP1  HOMDEL   6.5           6  116635618.0  116668794.0       3
# 12981    ZUP1  HOMDEL   6.3           6  116635618.0  116668794.0       3
# 12982    ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983     ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 2             Esophageal_Adenocarcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12980           Prostate_Adenocarcinoma
# 12981                    Uveal Melanoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [12984 rows x 8 columns]

# %%
first_data_adera1= first_data_adera.dropna(axis = 0, how ='any')
first_data_adera1
#first_data_adera2 = first_data_adera1.sort_values(by=['Freq'], ascending=[ False])
first_data_adera3 = first_data_adera1.sort_values(by=['Gene', 'Cancer_type', 'Freq'], ascending=[True, True, False])
first_data_adera3
first_data_adera4 = first_data_adera3.drop_duplicates(subset=['Gene'], keep='first')
first_data_adera4
# Out:
#           Gene     CNA  Freq  chromosome        start          end  strand  \
# 0        A2ML1     AMP   6.0          12    8822621.0    8887001.0      77
# 1        A4GNT     AMP   6.8           3  138123713.0  138132390.0       3
# 3       AACSP1     AMP   7.3           5  178764861.0  178818435.0       3
# 4        AADAC     AMP   8.2           3  151814073.0  151828488.0      77
# 7      AADACL2     AMP   8.2           3  151733916.0  151761339.0      77
# ...        ...     ...   ...         ...          ...          ...     ...
# 12977   ZSWIM4     AMP  12.1          19   13795443.0   13832254.0      77
# 12978   ZSWIM7     AMP   9.1          17   15976560.0   15999717.0       3
# 12979     ZUP1  HOMDEL   8.3           6  116635618.0  116668794.0       3
# 12982     ZXDC     AMP   6.1           3  126437601.0  126475891.0       3
# 12983      ZYX     AMP   8.0           7  143381295.0  143391111.0      77
#
#                             Cancer_type
# 0           Testicular_Germ_Cell_Tumors
# 1      Cervical_Squamous_Cell_Carcinoma
# 3            Renal_Clear_Cell_Carcinoma
# 4      Cervical_Squamous_Cell_Carcinoma
# 7      Cervical_Squamous_Cell_Carcinoma
# ...                                 ...
# 12977             Serous_Ovarian_Cancer
# 12978                           Sarcoma
# 12979     Diffuse_Large B-Cell_Lymphoma
# 12982  Cervical_Squamous_Cell_Carcinoma
# 12983             Serous_Ovarian_Cancer
#
# [7058 rows x 8 columns]

# %%
first_data_adera["Cancer_type"].unique()
# Out:
# array(['Testicular_Germ_Cell_Tumors', 'Cervical_Squamous_Cell_Carcinoma',
#        'Esophageal_Adenocarcinoma', 'Renal_Clear_Cell_Carcinoma',
#        'Head_and_Neck_Squamous', 'Serous_Ovarian_Cancer',
#        'Colorectal_Adenocarcinoma', 'Liver_Hepatocellular_Carcinoma',
#        'Breast_Invasive_Ductal_Carcinoma', 'Stomach_Adenocarcinoma',
#        'Uterine_Corpus_Endometrial_Carcinoma',
#        'Diffuse_Large B-Cell_Lymphoma', 'Cholangiocarcinoma',
#        'Uveal Melanoma', 'Bladder_Urothelial_Carcinoma', 'Sarcoma',
#        'Prostate_Adenocarcinoma', 'Lung', 'Adrenocortical_Carcinoma',
#        'Glioblastoma_Multiforme', 'Skin_Cutaneous_Melanoma',
#        'Brain_Lower_Grade_Glioma'], dtype=object)

# %%
#First_data_adera3a= first_data_adera3[first_data_adera3['Cancer_type'] == 'Esophageal_Adenocarcinoma']
First_data_adera3b1= first_data_adera3[first_data_adera3['Cancer_type'] == 'Colorectal_Adenocarcinoma']
First_data_adera3b2= first_data_adera3[first_data_adera3['Cancer_type'] == 'Cholangiocarcinoma']
#First_data_adera3b3= first_data_adera3[first_data_adera3['Cancer_type'] == 'Stomach_Adenocarcinoma']
First_data_adera3b3= first_data_adera3[first_data_adera3['Cancer_type'] == 'Cervical_Squamous_Cell_Carcinoma']


#First_data_adera3c = pd.concat([First_data_adera3a, First_data_adera3b1,First_data_adera3b2,First_data_adera3b3])
#First_data_adera3c = pd.concat([First_data_adera3b1, First_data_adera3b2,First_data_adera3b3])
First_data_adera3c = pd.concat([First_data_adera3b1,First_data_adera3b2])

# %%
First_data_adera3c
import pandas as pd


# Get unique cancer types in the dataset
unique_cancer_types = First_data_adera3c['Cancer_type'].unique()

# Count the rows for each cancer type
for cancer_type in unique_cancer_types:
    cancer_type_data = First_data_adera3c[First_data_adera3c['Cancer_type'] == cancer_type]
    num_rows = len(cancer_type_data)
    print("Number of rows in", cancer_type, ":", num_rows)
# Out:
# Number of rows in Colorectal_Adenocarcinoma : 442
# Number of rows in Cholangiocarcinoma : 675

# %%
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Esophageal_Adenocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Colorectal_Adenocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Cholangiocarcinoma']
#first_data_adera3[first_data_adera3['Cancer_type'] == 'Stomach_Adenocarcinoma']

# %%
import tensorflow.keras
import tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(First_data_adera3c["CNA"])
Adera_CNA= encoder.transform(First_data_adera3c["CNA"])

Adera_CNA1= to_categorical(Adera_CNA,num_classes=4)
#type(first_data_adera["Freq"])
#Adera_CNA1=first_data_adera['CNA']
Adera_CNA1.shape #rember to update because there are genes written in one or more diseases.
Adera_CNA1
type(First_data_adera3c ['CNA'])

#Input_net_Adera = np.concatenate((Adera_freq.T,Adera_CNA1), axis=None)
#Input_net_Adera1=Input_net_Adera.reshape(5,6918).T

Input_net_Adera1=Adera_CNA1
Input_net_Adera1.shape # number of samples,number of 4 states
Adera_chromosome=First_data_adera3c['chromosome']
Adera_chromosome1=np.array(Adera_chromosome)
Adera_chromosome2=Adera_chromosome1.reshape(Input_net_Adera1.shape[0],1)

Adera_start=First_data_adera3c['start']
Adera_start1=np.array(Adera_start)
Adera_start2=Adera_start1.reshape(Input_net_Adera1.shape[0],1)

Adera_end=First_data_adera3c['end']
Adera_end1=np.array(Adera_end)
Adera_end2=Adera_end1.reshape(Input_net_Adera1.shape[0],1)

Adera_strand=First_data_adera3c['strand']
Adera_strand1=np.array(Adera_strand)
Adera_strand2=Adera_strand1.reshape(Input_net_Adera1.shape[0],1)

Adera_freq=First_data_adera3c['Freq']
Adera_freq1=np.array(Adera_freq)
Adera_freq2=Adera_freq1.reshape(Input_net_Adera1.shape[0],1)
#normalise chromsoem numbers
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_chromosome3 = Adera_chromosome2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_chromosome4= scaler.fit_transform(Adera_chromosome3)



#####normalise start values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_start3 = Adera_start2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_start4= scaler.fit_transform(Adera_start3)

####normalise end values
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_end3 = Adera_end2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_end4= scaler.fit_transform(Adera_end3)

######normalise stand
from sklearn.preprocessing import MinMaxScaler
import numpy as np
Adera_strand3 = Adera_strand2.reshape(-1, 1)
scaler = MinMaxScaler()
Adera_strand4= scaler.fit_transform(Adera_strand3)
Adera_chromosome4.shape
k1=First_data_adera3c["Cancer_type"].unique()
k1.shape[0]
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,adera_matrix), axis=1)
Adera_CNA1
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome2,Adera_start2,Adera_end2,Adera_strand2,Adera_freq2), axis=1)
Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_chromosome4,Adera_start4,Adera_end4,Adera_strand4), axis=1)
#Input_net_Adera2 = np.concatenate((Input_net_Adera1,Adera_start2,Adera_end2), axis=1)
#Input_net_Adera2=adera_matrix
Input_net_Adera2.shape
Output_net_Adera=First_data_adera3c[["Cancer_type"]]
Output_net_Adera

from sklearn.preprocessing import LabelEncoder
#encoder = LabelEncoder()
#encoder.fit(Output_net_Adera)
#Output_net_Adera1 = encoder.transform(Output_net_Adera)

#Output_net_Adera1 = np_utils.to_categorical(Output_net_Adera1,num_classes=3)
#Output_net_Adera1



encoder = LabelEncoder()
encoder.fit(First_data_adera3c[["Cancer_type"]])
Output_net_Adera1 = encoder.transform(First_data_adera3c[["Cancer_type"]])

Output_net_Adera2=to_categorical(Output_net_Adera1 ,num_classes=k1.shape[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
Output_net_Adera2= to_categorical(Output_net_Adera1 ,num_classes=k1.shape[0])
Output_net_Adera2.shape
Output_net_Adera2
Input_Adera_numpy2=Input_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,8) #7 input values

Output_net_Adera3=Output_net_Adera2.reshape(Input_net_Adera1.shape[0],1,1,k1.shape[0]) #7 cancer types
Output_net_Adera3.shape
# Out:
# (1117, 1, 1, 2)

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.metrics import SpecificityAtSensitivity, AUC
#from tensorflow.keras import regularizers
import numpy as np
#result_file = open("results_adera1.txt", "w")
#result_file.write(" test_adera")
#result_file.close()

# %%
#from tensorflow.keras import regularizers
es_ADERA = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=300)

from random import sample

class_0_indices = np.where(Output_net_Adera3 == 0)[0]
class_1_indices = np.where(Output_net_Adera3 == 1)[0]

num_samples_class_0 = len(class_0_indices)
num_samples_class_1 = len(class_1_indices)

target_size = min(num_samples_class_0, num_samples_class_1)

undersampled_indices = np.concatenate([
    sample(class_0_indices.tolist(), target_size),
    class_1_indices
])

Input_Adera_undersampled = Input_Adera_numpy2[undersampled_indices]
Output_net_Adera_undersampled = Output_net_Adera3[undersampled_indices]




grace_model = tf.keras.Sequential([
 tf.keras.layers.Dense(128, activation='relu'),
 # tf.keras.layers.Dense(2, activation='softmax'),
 #tf.keras.layers.Dense(2, activation='sigmoid'),

 tf.keras.layers.Dense(2, activation='softplus')


      ])





optimizer_Adera=tf.keras.optimizers.Adamax(learning_rate=0.08*1e-1, clipnorm = .018)
grace_model.compile(optimizer=optimizer_Adera, loss='CategoricalFocalCrossentropy', metrics=[ 'accuracy', SpecificityAtSensitivity(0.5),AUC()  ])
#grace_model.compile(optimizer=optimizer_Adera, loss='binary_crossentropy', metrics=['accuracy'])
k_adera = grace_model.fit(Input_Adera_undersampled, Output_net_Adera_undersampled, verbose=1, validation_split=0.41, epochs=50, batch_size=250, callbacks=[es_ADERA])
#k_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=0,validation_split=0.40,epochs=50,batch_size=250, callbacks=[es_ADERA])

#k_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=200,batch_size=10, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8_adera=grace_model.fit(Input_Adera_numpy2,Output_net_Adera3,verbose=1,validation_split=0.49,epochs=350,batch_size=250, callbacks=[es_ADERA]) # TEST1_TRAIN_0.8
# Out:
# Epoch 1/50
# 6/6 [==============================] - 2s 86ms/step - loss: 0.0256 - accuracy: 0.9105 - specificity_at_sensitivity_3: 0.9431 - auc_3: 0.9506 - val_loss: 0.0105 - val_accuracy: 0.9727 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9987
# Epoch 2/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0067 - accuracy: 0.9788 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9985 - val_loss: 0.0036 - val_accuracy: 0.9716 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9980
# Epoch 3/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0029 - accuracy: 0.9803 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9980 - val_loss: 0.0031 - val_accuracy: 0.9716 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9979
# Epoch 4/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0025 - accuracy: 0.9788 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9976 - val_loss: 0.0025 - val_accuracy: 0.9836 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9979
# Epoch 5/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0022 - accuracy: 0.9879 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9973 - val_loss: 0.0023 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9977
# Epoch 6/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0021 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9967 - val_loss: 0.0022 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9976
# Epoch 7/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9965 - val_loss: 0.0021 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9976
# Epoch 8/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9963 - val_loss: 0.0020 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9976
# Epoch 9/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9964 - val_loss: 0.0020 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9976
# Epoch 10/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9964 - val_loss: 0.0020 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9976
# Epoch 11/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0018 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9962 - val_loss: 0.0018 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 12/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 0.9901 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9953 - val_loss: 0.0018 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9972
# Epoch 13/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 0.9909 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9958 - val_loss: 0.0019 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 14/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9961 - val_loss: 0.0019 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 15/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0017 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9962 - val_loss: 0.0019 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 16/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0017 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9958 - val_loss: 0.0017 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9973
# Epoch 17/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9952 - val_loss: 0.0017 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 18/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9950 - val_loss: 0.0017 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9973
# Epoch 19/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9948 - val_loss: 0.0016 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9973
# Epoch 20/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 0.9901 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9948 - val_loss: 0.0016 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9974
# Epoch 21/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 0.9909 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9948 - val_loss: 0.0016 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9973
# Epoch 22/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0016 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9950 - val_loss: 0.0016 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9972
# Epoch 23/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9946 - val_loss: 0.0015 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 24/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0015 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9944 - val_loss: 0.0016 - val_accuracy: 0.9902 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 25/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0015 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9947 - val_loss: 0.0016 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9973
# Epoch 26/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0015 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9949 - val_loss: 0.0016 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9972
# Epoch 27/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0015 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9944 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 28/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0015 - accuracy: 0.9917 - specificity_at_sensitivity_3: 0.9977 - auc_3: 0.9941 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 29/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9943 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9972
# Epoch 30/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9947 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9972
# Epoch 31/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9944 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 32/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9939 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 33/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9935 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 34/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9992 - auc_3: 0.9940 - val_loss: 0.0015 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 35/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9938 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9968
# Epoch 36/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9929 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9969
# Epoch 37/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 0.9924 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9936 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 38/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9940 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 39/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 0.9924 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9939 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 40/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 0.9924 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9928 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9966
# Epoch 41/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9923 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9967
# Epoch 42/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 0.9985 - auc_3: 0.9927 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9969
# Epoch 43/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9937 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970
# Epoch 44/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9943 - val_loss: 0.0014 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9971
# Epoch 45/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9939 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9969
# Epoch 46/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9934 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9968
# Epoch 47/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9933 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9969
# Epoch 48/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9929 - val_loss: 0.0012 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9967
# Epoch 49/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9925 - val_loss: 0.0012 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9968
# Epoch 50/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 0.9939 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9934 - val_loss: 0.0013 - val_accuracy: 0.9913 - val_specificity_at_sensitivity_3: 1.0000 - val_auc_3: 0.9970

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
# summarize history for accuracy
plt.plot(k_adera.history['accuracy'])
plt.plot(k_adera.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
axes = plt.gca()
#axes.set_ylim([-0.005,0.005])
plt.plot(k_adera.history['loss'])
plt.plot(k_adera.history['val_loss'])
#########################
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
#plt.title('model mape')
#plt.plot(k_adera.history['mean_squared_error'])
#plt.plot(k_adera.history['val_mape'])
#plt.plot(k_adera.history['mape'])
#plt.ylabel('mape')
#plt.xlabel('epoch')
#plt.show()
#plt.title('model mae')
#plt.plot(k_adera.history['val_mae'])
#plt.plot(k_adera.history['mae'])
#plt.show()
# Out:
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9928 - specificity_at_sensitivity_2: 0.9973 - auc_2: 0.9961

# %%
#print(k_adera.history.keys())
#print(k_adera.history['val_loss'])
#print(k_adera.history['val_accuracy'])
#print(k_adera.history['mape'])
results = grace_model.evaluate(Input_Adera_numpy2,Output_net_Adera3,batch_size=400)
# Out:
# 3/3 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.9928 - specificity_at_sensitivity_3: 1.0000 - auc_3: 0.9953

# %%
# Plotting multiple metrics
plt.figure(figsize=(16, 5))

# Plot Accuracy
plt.subplot(1, 3, 1)
plt.plot(k_adera.history['accuracy'])
plt.plot(k_adera.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
ax = plt.gca()
ax.set_ylim([0.9, 1])

# Plot Loss
plt.subplot(1, 3, 2)
plt.plot(k_adera.history['loss'])
plt.plot(k_adera.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot Specificity at Sensitivity 0.5
plt.subplot(1, 3, 3)
plt.plot(k_adera.history['specificity_at_sensitivity_3'])
plt.plot(k_adera.history['val_specificity_at_sensitivity_3'])
plt.title('Specificity at Sensitivity 0.5')
plt.ylabel('Specificity')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# Plot AUC
plt.figure(figsize=(8, 5))
plt.plot(k_adera.history['auc_3'])
plt.plot(k_adera.history['val_auc_3'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
grace_model.save("adera+99+99+softmax+digetsive+system")

# %%
adera_47_40_model = tf.keras.saving.load_model("adera+95+95+sigmoid+digetsive+system")

# %%
First_data_adera3c["Cancer_type"].unique()
data_adera= {
    "types":First_data_adera3c["Cancer_type"].unique(),
    "values": [0, 1]
}

data_adera
# Out:
# {'types': array(['Colorectal_Adenocarcinoma', 'Cholangiocarcinoma'], dtype=object),
#  'values': [0, 1]}

# %%
from sklearn.metrics import confusion_matrix
print("ok")
y_true_adera=[]
y_pred_adera=[]
print(y_true_adera)
print(y_pred_adera)
print("ok2")


#mkr1=confusion_matrix(y_true_adera, y_pred_adera, labels=['Colorectal_Adenocarcinoma', 'Cholangiocarcinoma'],normalize='all')

First_data_adera3c["Cancer_type"].unique()
import random

data_adera= {
    "types":First_data_adera3c["Cancer_type"].unique(),

}

data_adera

threshold = 1 # Set the threshold for prediction
num_runs = 3

y_true_adera=[]
y_pred_adera=[]


for run in range(num_runs):
    adera_test = [random.randint(0, Adera_chromosome4.shape[0]-1) for _ in range(99)]

    for adera_test1 in adera_test:
        test_mac = Input_Adera_numpy2[adera_test1].reshape(1, 1, 1, 8)
        adera_result = grace_model.predict(test_mac)
        #print("adera_result=",adera_result)


        adera_result_thresholded = (adera_result >= threshold).astype(int)
        #print(adera_result_thresholded)
        adera_result5 = np.argmax(adera_result_thresholded)
       # print("adera_result5=",adera_result5)
        y_true_adera.append(First_data_adera3c['Cancer_type'].iloc[adera_test1])
        y_pred_adera.append(data_adera['types'][adera_result5])


#print(y_true_adera)
#print(y_pred_adera)


from sklearn.metrics import confusion_matrix

print(y_true_adera)
print(y_pred_adera)
# Out:
# ok
# []
# []
# ok2
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ['Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholang ...
# ['Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma', 'Colorectal_Adenocarcinoma', 'Cholangiocarcinoma', 'Cholangiocarcinoma', 'Colorectal_Adenocarcinoma ...

# %%
from sklearn.metrics import multilabel_confusion_matrix
#multilabel_confusion_matrix


#array([[2, 0, 0],
 #      [0, 0, 1],
   #3    [1, 0, 2]])

mkr1=confusion_matrix(y_true_adera, y_pred_adera, labels=[First_data_adera3c["Cancer_type"].unique()[0],
                                                          First_data_adera3c["Cancer_type"].unique()[1]]  ,normalize='all')
                                                  # First_data_adera3c["Cancer_type"].unique()[2]]

mkr1
from sklearn.metrics import classification_report

print(classification_report(y_true_adera, y_pred_adera))


#mkr2=np.array([[2, 0, 0],
 #      [0, 0, 1],
  #     [1, 0, 2]])
#print(mkr2)
#from matplotlib.ticker import MultipleLocator; ax.xaxis.set_major_locator(MultipleLocator(1)); ax.yaxis.set_major_locator(MultipleLocator(1))
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

mkr1_display = ConfusionMatrixDisplay(mkr1).plot()
# Out:
#                            precision    recall  f1-score   support
#
#        Cholangiocarcinoma       0.01      0.01      0.01       195
# Colorectal_Adenocarcinoma       0.01      0.02      0.01       102
#
#                  accuracy                           0.01       297
#                 macro avg       0.01      0.01      0.01       297
#              weighted avg       0.01      0.01      0.01       297
